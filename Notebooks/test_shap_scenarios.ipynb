# %%
import pandas as pd

# 1. The "Clearly Healthy" Patient
# Normal heart rate, normal blood pressure, normal temp.
healthy_patient = {
    "heart_rate": 75.0,
    "resp_rate": 16.0,
    "sbp": 120.0,
    "map_bp": 90.0,
    "temp_c": 37.0,
    "spo2": 99.0,
    "hr_rolling_mean": 74.5,
    "hr_rolling_std": 2.0,
    "map_rolling_mean": 91.0,
    "map_rolling_std": 3.0,
    "shock_index": 75.0 / 120.0  # 0.625 (Normal is < 0.7)
}

# 2. The "Clearly Deteriorating" Patient (Septic Shock profile)
# High heart rate, dangerously low blood pressure, fever.
deteriorating_patient = {
    "heart_rate": 135.0,
    "resp_rate": 28.0,
    "sbp": 85.0,
    "map_bp": 55.0,
    "temp_c": 39.2,
    "spo2": 92.0,
    "hr_rolling_mean": 120.0,
    "hr_rolling_std": 15.0,
    "map_rolling_mean": 65.0,
    "map_rolling_std": 10.0,
    "shock_index": 135.0 / 85.0  # 1.58 (Dangerously high!)
}

# 3. The "Ambiguous" Patient
# Slightly elevated heart rate, but normal blood pressure. 
# Are they getting Sepsis, or just stressed/in pain?
ambiguous_patient = {
    "heart_rate": 98.0,
    "resp_rate": 20.0,
    "sbp": 115.0,
    "map_bp": 85.0,
    "temp_c": 37.8,
    "spo2": 96.0,
    "hr_rolling_mean": 95.0,
    "hr_rolling_std": 5.0,
    "map_rolling_mean": 86.0,
    "map_rolling_std": 4.0,
    "shock_index": 98.0 / 115.0  # 0.85 (Borderline)
}

# Convert them to a Pandas DataFrame
test_cases = pd.DataFrame([healthy_patient, deteriorating_patient, ambiguous_patient], 
                          index=["Healthy", "Deteriorating", "Ambiguous"])

# %%
# Import your specific function (adjust this import to match your actual code structure)
# from ml.inference.explain import explain_row 

print("--- Testing Healthy Patient ---")
# explain_row(test_cases.loc[["Healthy"]])

print("\n--- Testing Deteriorating Patient ---")
# explain_row(test_cases.loc[["Deteriorating"]])

print("\n--- Testing Ambiguous Patient ---")
# explain_row(test_cases.loc[["Ambiguous"]])
# Out:
# --- Testing Healthy Patient ---
#
# --- Testing Deteriorating Patient ---
#
# --- Testing Ambiguous Patient ---
